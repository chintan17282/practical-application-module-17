# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from utils.common_plot_tetha import plot_model
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, OrdinalEncoder
from sklearn.compose import make_column_selector, make_column_transformer, ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_text, plot_tree
from sklearn.metrics import ConfusionMatrixDisplay
from imblearn.ensemble import BalancedBaggingClassifier
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, make_scorer, confusion_matrix, fbeta_score
from sklearn.feature_selection import SelectFromModel
from pprint import pprint
import warnings
warnings.filterwarnings("ignore") 
from sklearn import set_config
set_config(display='diagram')

# %% [markdown]
# # 1. Read Data

# %%
df = pd.read_csv('bank+marketing/bank_clean.csv')

# %% [markdown]
# # 2. Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['balance','y','previous','poutcome','default'], axis=1), df['y'], test_size = 0.3, random_state = 42)

# %% [markdown]
# # 3. Column Transformation
# - OneHotEncoder for 'job','marital', 'contact', 'default', 'housing', 'loan', 'contact', 'month','poutcome'
# - OrdinalEncoder for education

# %%
education_categories = [['illiterate', 'basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'university.degree','professional.course']]
one_hot_encoding_features = ['job','marital', 'contact', 'housing', 'loan', 'month']

transformer = make_column_transformer(    
    (OneHotEncoder(),one_hot_encoding_features),
    (OrdinalEncoder(categories=education_categories, unknown_value=-1, handle_unknown='use_encoded_value'),['education']),
    remainder = StandardScaler()
)

# %% [markdown]
# # 4. Pipeline

# %%
pipeline = Pipeline([
    ('transformer', transformer),     
    ('classifier', BalancedBaggingClassifier(
        estimator=DecisionTreeClassifier(random_state=42),
        n_estimators=50, 
        sampling_strategy='auto',  
        replacement=False, 
        random_state=42,
        n_jobs=-1                  
    ))
])

# %% [markdown]
# ## 4.1 Plain Vanila fitting

# %%
pipeline.fit(X_train,y_train);

# %%
train_acc = pipeline.score(X_train, y_train)
test_acc = pipeline.score(X_test, y_test)

# %%
print(f'Training Accuracy: {train_acc: .2f}')
print(f'Test Accuracy:     {test_acc: .2f}')
# Out:
# Training Accuracy:  0.90
# Test Accuracy:      0.87

# %% [markdown]
# ## 4.2. Determining parameters for DecisionTreeClassifier

# %%
def DetermineParameter(decision_classifier, parameter, parameters_list):
    train_accuracies = []
    test_accuracies = []

    for para in parameters_list:
        kwargs = {
            "random_state": 42,
            "class_weight":{'yes':1, 'no':9},
            parameter: para
        }
        pipeline = pipeline = Pipeline([
                    ('transformer', transformer),     
                    ('classifier', decision_classifier(**kwargs))
        ])    
        pipeline.fit(X_train, y_train)
        y_train_pred = pipeline.predict(X_train)
        y_test_pred = pipeline.predict(X_test)
        
        # Calculate and collect accuracies
        train_accuracies.append(accuracy_score(y_train, y_train_pred))
        test_accuracies.append(accuracy_score(y_test, y_test_pred))

    plt.figure(figsize=(20, 8))
    plt.plot(parameters_list, train_accuracies, label='Training Accuracy', marker='o')
    plt.plot(parameters_list, test_accuracies, label='Test Accuracy', marker='o')
    plt.xlabel(f'{parameter.replace("_"," ")}')
    plt.ylabel('Accuracy')
    plt.title(f'Accuracy vs. Tree {parameter.replace("_"," ")}')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# ### max_depth
# - Purpose: Limits the depth (number of levels) of the tree.<br>
# - Tip: A very deep tree can overfit; setting a maximum depth helps control model complexity.

# %%
DetermineParameter(DecisionTreeClassifier,"max_depth", range(4,20))

# %% [markdown]
# ### min_samples_split
# - Purpose: The minimum number of samples required to split an internal node.
# - Tip: Increasing this value can make the tree more general and reduce overfitting.

# %%
DetermineParameter(DecisionTreeClassifier,"min_samples_split", np.linspace(0.02,0.25,23))

# %% [markdown]
# ### min_samples_leaf
# - Purpose: The minimum number of samples required to be at a leaf node.
# - Tip: Larger values can reduce variance (smoothing the model), which might help avoid overfitting.

# %%
DetermineParameter(DecisionTreeClassifier,"min_samples_leaf", np.linspace(0.01,0.1,10))

# %% [markdown]
# ### max_leaf_nodes
# - Purpose: Limits the number of leaf nodes in the tree.
# - Tip: It can be used as an alternative to max_depth to control complexity.

# %%
DetermineParameter(DecisionTreeClassifier,"max_leaf_nodes", range(8,64,2))

# %% [markdown]
# ### max_features
# - Purpose: The number of features to consider when looking for the best split.

# %%
DetermineParameter(DecisionTreeClassifier,"max_features", np.linspace(0.05, 0.5, 45))

# %% [markdown]
# ### min_impurity_decrease
# - A node will be split if this split induces a decrease of the impurity greater than or equal to this value.

# %%
DetermineParameter(DecisionTreeClassifier,"min_impurity_decrease", np.linspace(0.1, 0.5, 10))

# %% [markdown]
# # 5. Pipeline - 1

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "fbeta_score"<br>
# - Followed by which we are doing Feature Selection <br>
# - Ensemble Algorithm - BalancedBaggingClassifier with estimator as DecisionTreeClassifier  <br>
# - HyperParameter Tuning using GridSearchCV<br>
# </div>

# %%
pipeline1 = Pipeline([
    ('transformer', transformer),     
    ('classifier', BalancedBaggingClassifier(
        estimator=DecisionTreeClassifier(random_state=42),
        n_estimators=50, 
        sampling_strategy='auto',  
        replacement=False, 
        random_state=42,
        n_jobs=-1                  
    ))
])

# %% [markdown]
# ## 5.1 GridSearchCV

# %%
params1 = [
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_depth': list(range(8, 12, 1)),
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8), 
         'classifier__estimator__min_impurity_decrease': [0.01, 0.02]
    },    
    {
        'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
        'classifier__estimator__criterion': ["gini", "entropy"],
        'classifier__estimator__min_samples_leaf': np.linspace(0.01,0.2,10)
    },
    {
        'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
        'classifier__estimator__criterion': ["gini", "entropy"],
        'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8)
    },
    {
        'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
        'classifier__estimator__criterion': ["gini", "entropy"],
        'classifier__estimator__max_leaf_nodes':list(range(56,66,2))
    },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__max_depth': list(range(8, 12, 1)),
     },
         {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__min_impurity_decrease':[0.01, 0.02]
     }

]

# %%
cv1 = GridSearchCV(pipeline1, param_grid=params1, n_jobs=-1, verbose=True, scoring=make_scorer(fbeta_score, beta=2, pos_label='yes'))

# %% [markdown]
# ## 5.2. Fitting the LogisticRegression Model

# %%
cv1.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 384 candidates, totalling 1920 fits

# %%
pprint(cv1.best_params_)
# Out:
# {'classifier__estimator__criterion': 'entropy',
#  'classifier__estimator__max_depth': 11,
#  'classifier__sampling_strategy': 'majority'}

# %% [markdown]
# ## 5.3. Predictions

# %%
plot_model(cv1, X_test, y_test)

# %%
# y_pred_1 = cv1.predict(X_test)
probs = cv1.predict_proba(X_test)
y_pred_1 = np.where(probs[:, 1] >= 0.70,  'yes','no')

# %% [markdown]
# ## 5.4. Scoring

# %% [markdown]
# ### Accuracy
# Q) Out of the predictions made by the model, what percent is correct?
# <div align="center">
# $Accuracy =\Large \frac{(TP+TN))}{(TP+TN+FP+FN)}$
# </div>

# %%
accuracy = accuracy_score(y_test, y_pred_1)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8990855385611395

# %% [markdown]
# ### Precision Score
# Q) Out of all the YES predictions, how many of them were correct?
# <div align="center">
# $Precision = \Large\frac{TP}{TP+FP}$
# </div>

# %%
p_score = precision_score(y_test, y_pred_1,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.4498257839721254

# %% [markdown]
# ### Recall Score
# Q) Of all the actual positive cases, how many did the model capture?
# <div align="center">
# $Recall = \Large\frac{TP}{TP+FN}$
# </div>

# %%
r_score = recall_score(y_test, y_pred_1,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.9294456443484521

# %% [markdown]
# ### F1 Score
# <div align="center">
# $F1 = \Large\frac{2*TP}{2*TP+FP+FN}$
# </div>

# %%
f_1_score = f1_score(y_test, y_pred_1, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6062455975581122

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_1).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9389), np.int64(1579), np.int64(98), np.int64(1291))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_1);

# %% [markdown]
# # 6. Pipeline - 2

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "fbeta_score"<br>
# - Followed by which we are doing Feature Selection <br>
# - Ensemble Algorithm - BalancedBaggingClassifier with estimator as DecisionTreeClassifier  <br>
# - HyperParameter Tuning using GridSearchCV<br>
# </div>

# %%
pipeline2 = Pipeline([
    ('transformer', transformer),     
    ('feature_selection', SelectFromModel(estimator=LogisticRegression(random_state=43, max_iter = 1000, C= 0.1, penalty= 'l1',solver= 'liblinear'))),
    ('classifier', BalancedBaggingClassifier(
        estimator=DecisionTreeClassifier(random_state=42),
        n_estimators=50, 
        sampling_strategy='auto',  
        replacement=False, 
        random_state=42,
        n_jobs=-1                  
    ))
])

# %% [markdown]
# ## 6.1 GridSearchCV

# %%
params2 = [
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8),
         'classifier__estimator__min_impurity_decrease': [0.01, 0.02]
    },    
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__min_samples_leaf': np.linspace(0.01,0.2,10)
    },
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8)
    },
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_leaf_nodes':list(range(56,66,2)),
    },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
     },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__min_impurity_decrease':[0.01, 0.02]
     }
]

# %%
cv2 = GridSearchCV(pipeline2, param_grid=params2, n_jobs=-1, verbose=True, scoring=make_scorer(fbeta_score, beta=2, pos_label='yes'))

# %% [markdown]
# ## 6.2. Fitting the Model

# %%
cv2.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 1154 candidates, totalling 5770 fits

# %%
pprint(cv2.best_params_)
# Out:
# {'classifier__estimator__criterion': 'entropy',
#  'classifier__estimator__max_depth': 16,
#  'classifier__sampling_strategy': 'majority'}

# %% [markdown]
# ## 6.3. Predictions

# %%
plot_model(cv2, X_test, y_test)

# %%
# y_pred_2 = cv2.predict(X_test)
probs = cv2.predict_proba(X_test)
y_pred_2 = np.where(probs[:, 1] >= 0.65,  'yes','no')

# %% [markdown]
# ## 6.4. Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_2)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8930970300234685

# %%
p_score = precision_score(y_test, y_pred_2,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.5155677655677655

# %%
r_score = recall_score(y_test, y_pred_2,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.8106551475881929

# %%
f_1_score = f1_score(y_test, y_pred_2, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.630282675622726

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_2).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9910), np.int64(1058), np.int64(263), np.int64(1126))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_2);

# %% [markdown]
# # 7. Pipeline - 3

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "recall_score"<br>
# - Followed by which we are doing Feature Selection <br>
# - Ensemble Algorithm - BalancedBaggingClassifier with estimator as DecisionTreeClassifier  <br>
# - HyperParameter Tuning using GridSearchCV<br>
# </div>

# %%
pipeline3 = Pipeline([
    ('transformer', transformer),     
    ('feature_selection', SelectFromModel(estimator=LogisticRegression(random_state=43, max_iter = 1000, C= 0.1, penalty= 'l1',solver= 'liblinear'))),
    ('classifier', BalancedBaggingClassifier(
        estimator=DecisionTreeClassifier(random_state=42),
        n_estimators=50, 
        sampling_strategy='auto',  
        replacement=False, 
        random_state=42,
        n_jobs=-1                  
    ))
])

# %% [markdown]
# ## 7.1 GridSearchCV

# %%
params3 =  [
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8),
         'classifier__estimator__min_impurity_decrease': [0.01, 0.02]
    },    
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__min_samples_leaf': np.linspace(0.01,0.2,10)
    },
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8)
    },
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_leaf_nodes':list(range(56,66,2)),
    },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
     },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__min_impurity_decrease':[0.01, 0.02]
     }
]

# %%
cv3 = GridSearchCV(pipeline3, param_grid=params3, n_jobs=-1, verbose=True, scoring=make_scorer(recall_score, pos_label='yes'))

# %% [markdown]
# ## 7.2. Fitting the Model

# %%
cv3.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 1154 candidates, totalling 5770 fits

# %%
pprint(cv3.best_params_)
# Out:
# {'classifier__estimator__criterion': 'gini',
#  'classifier__estimator__min_impurity_decrease': 0.01,
#  'classifier__sampling_strategy': 'majority'}

# %% [markdown]
# ## 7.3. Predictions

# %%
plot_model(cv3, X_test, y_test)

# %%
# y_pred_3 = cv3.predict(X_test)
probs = cv3.predict_proba(X_test)
y_pred_3 = np.where(probs[:, 1] >= 0.55,  'yes','no')

# %% [markdown]
# ## 7.4. Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_3)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.817916970138383

# %%
p_score = precision_score(y_test, y_pred_3,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.3741596024554224

# %%
r_score = recall_score(y_test, y_pred_3,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.9215262778977682

# %%
f_1_score = f1_score(y_test, y_pred_3, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.5322245322245323

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_3).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(8827), np.int64(2141), np.int64(109), np.int64(1280))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_3);

# %% [markdown]
# # 8. Pipeline - 4

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "fbeta_score"<br>
# - Followed by which we are doing Feature Selection <br>
# - Ensemble Algorithm - BalancedBaggingClassifier with estimator as DecisionTreeClassifier with Class Weight<br>
# - HyperParameter Tuning using GridSearchCV<br>
# </div>

# %%
pipeline4 = Pipeline([
    ('transformer', transformer),     
    ('classifier', BalancedBaggingClassifier(
        estimator=DecisionTreeClassifier(random_state=42, class_weight='balanced'),
        n_estimators=50, 
        sampling_strategy='auto',  
        replacement=False, 
        random_state=42,
        n_jobs=-1                  
    ))
])

# %% [markdown]
# ## 8.1 GridSearchCV

# %%
params4 = [
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8),
         'classifier__estimator__min_impurity_decrease': [0.01, 0.02]
    },    
    {
        'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
        'classifier__estimator__criterion': ["gini", "entropy"],
        'classifier__estimator__min_samples_leaf': np.linspace(0.01,0.2,10)
    },
    {
        'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
        'classifier__estimator__criterion': ["gini", "entropy"],
        'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8)
    },
    {
        'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
        'classifier__estimator__criterion': ["gini", "entropy"],
        'classifier__estimator__max_leaf_nodes':list(range(56,66,2)),
    },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
     },
         {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__min_impurity_decrease':[0.01, 0.02]
     }

]

# %%
cv4 = GridSearchCV(pipeline4, param_grid=params4, n_jobs=-1, verbose=True, scoring=make_scorer(fbeta_score, beta=2, pos_label='yes'))

# %% [markdown]
# ## 8.2. Fitting the Model

# %%
cv4.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 1154 candidates, totalling 5770 fits

# %%
pprint(cv4.best_params_)
# Out:
# {'classifier__estimator__criterion': 'entropy',
#  'classifier__estimator__max_depth': 17,
#  'classifier__sampling_strategy': 'majority'}

# %% [markdown]
# ## 8.3. Predictions

# %%
plot_model(cv5, X_test, y_test)

# %%
# y_pred_4 = cv4.predict(X_test)
probs = cv4.predict_proba(X_test)
y_pred_4 = np.where(probs[:, 1] >= 0.45,  'yes','no')

# %% [markdown]
# ## 8.4. Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_4)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8714898438132233

# %%
p_score = precision_score(y_test, y_pred_4,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.46359312111233075

# %%
r_score = recall_score(y_test, y_pred_4,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.912167026637869

# %%
f_1_score = f1_score(y_test, y_pred_4, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6147501213003397

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_4).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9502), np.int64(1466), np.int64(122), np.int64(1267))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_4);

# %% [markdown]
# # 9. Pipeline - 5

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "fbeta_score"<br>
# - Followed by which we are doing Feature Selection <br>
# - Ensemble Algorithm - BalancedBaggingClassifier with estimator as DecisionTreeClassifier with class weight <br>
# - Followed by which we are doing Feature Selection <br>
# - HyperParameter Tuning using GridSearchCV<br>
# </div>

# %%
pipeline5 = Pipeline([
    ('transformer', transformer),     
    ('feature_selection', SelectFromModel(estimator=LogisticRegression(random_state=43, max_iter = 1000, C= 0.1, penalty= 'l1',solver= 'liblinear'))),
    ('classifier', BalancedBaggingClassifier(
        estimator=DecisionTreeClassifier(random_state=42, class_weight='balanced'),
        n_estimators=50, 
        sampling_strategy='auto',  
        replacement=False, 
        random_state=42,
        n_jobs=-1                  
    ))
])

# %% [markdown]
# ## 9.1 GridSearchCV

# %%
params5 =  [
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8),
         'classifier__estimator__min_impurity_decrease': [0.01, 0.02]
    },    
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__min_samples_leaf': np.linspace(0.01,0.2,10)
    },
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8)
    },
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_leaf_nodes':list(range(56,66,2)),
    },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
     },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__min_impurity_decrease':[0.01, 0.02]
     }
]

# %%
cv5 = GridSearchCV(pipeline5, param_grid=params5, n_jobs=-1, verbose=True, scoring=make_scorer(fbeta_score, beta=2, pos_label='yes'))

# %% [markdown]
# ## 9.2. Fitting the Model

# %%
cv5.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 1154 candidates, totalling 5770 fits

# %%
pprint(cv5.best_params_)
# Out:
# {'classifier__estimator__criterion': 'entropy',
#  'classifier__estimator__max_depth': 16,
#  'classifier__sampling_strategy': 'majority'}

# %% [markdown]
# ## 9.3. Predictions

# %%
plot_model(cv5, X_test, y_test)

# %%
# y_pred_5 = cv5.predict(X_test)
probs = cv5.predict_proba(X_test)
y_pred_5 = np.where(probs[:, 1] >= 0.45,  'yes','no')

# %% [markdown]
# ## 9.4. Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_5)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8674435542607429

# %%
p_score = precision_score(y_test, y_pred_5,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.4549402823018458

# %%
r_score = recall_score(y_test, y_pred_5,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.9049676025917927

# %%
f_1_score = f1_score(y_test, y_pred_5, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6054913294797688

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_5).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9462), np.int64(1506), np.int64(132), np.int64(1257))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_5);

# %% [markdown]
# # 10. Pipeline - 6

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "fbeta_score"<br>
# - Followed by which we are doing Feature Selection <br>
# - Ensemble Algorithm - BalancedBaggingClassifier with estimator as DecisionTreeClassifier with class weight <br>
# - Followed by which we are doing Feature Selection <br>
# - HyperParameter Tuning using GridSearchCV<br>
# </div>

# %%
pipeline6 = Pipeline([
    ('transformer', transformer),     
    ('feature_selection', SelectFromModel(estimator=LogisticRegression(random_state=43, max_iter = 1000, C= 0.1, penalty= 'l1',solver= 'liblinear'))),
    ('classifier', BalancedBaggingClassifier(
        estimator=DecisionTreeClassifier(random_state=42, class_weight='balanced'),
        n_estimators=50, 
        sampling_strategy='auto',  
        replacement=False, 
        random_state=42,
        n_jobs=-1                  
    ))
])

# %% [markdown]
# ## 10.1 GridSearchCV

# %%
params6 =  [
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8),
         'classifier__estimator__min_impurity_decrease': [0.01, 0.02]
    },    
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__min_samples_leaf': np.linspace(0.01,0.2,10)
    },
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__min_samples_split': np.linspace(0.02,0.10,8)
    },
    {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],
         'classifier__estimator__max_leaf_nodes':list(range(56,66,2)),
    },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__max_depth': list(range(15, 30, 1)),
     },
     {
         'classifier__sampling_strategy': ['sampling_strategy', 'not majority','majority'],
         'classifier__estimator__criterion': ["gini", "entropy"],  
         'classifier__estimator__min_impurity_decrease':[0.01, 0.02]
     }
]

# %%
cv6 = GridSearchCV(pipeline6, param_grid=params6, n_jobs=-1, verbose=True, scoring=make_scorer(precision_score, pos_label='yes'))

# %% [markdown]
# ## 10.2. Fitting the Model

# %%
cv6.fit(X_train, y_train);
# Out:
# Fitting 5 folds for each of 1154 candidates, totalling 5770 fits

# %%
pprint(cv6.best_params_)
# Out:
# {'classifier__estimator__criterion': 'entropy',
#  'classifier__estimator__max_depth': 24,
#  'classifier__sampling_strategy': 'not majority'}

# %% [markdown]
# ## 10.3. Predictions

# %%
plot_model(cv6, X_test, y_test)

# %%
# y_pred_6 = cv6.predict(X_test)
probs = cv6.predict_proba(X_test)
y_pred_6 = np.where(probs[:, 1] >= 0.40,  'yes','no')

# %% [markdown]
# ## 10.4. Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_6)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.905964230800356

# %%
p_score = precision_score(y_test, y_pred_6,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.5718809373020899

# %%
r_score = recall_score(y_test, y_pred_6,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.6501079913606912

# %%
f_1_score = f1_score(y_test, y_pred_6, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6084905660377359

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_6).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(10292), np.int64(676), np.int64(486), np.int64(903))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_6);

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>DecisionTreeClassification - Conclusion</h1>
# </div>

# %% [markdown]
# |                           | Model 1     | Model 2     | Model 3      | Model 4     | Model 5     | Model 6         |
# | :------------------------ | :---------- | :---------- | ------------ | ----------- | ----------- | --------------- |
# | Metric                    | fbeta_score | fbeta_score | recall_score | fbeta_score | fbeta_score | precision_score |
# | Data Sampling Algorithms  | Yes         | Yes         | Yes          | Yes         | Yes         | Yes             |
# | Cost-Sensitive Algorithms | No          | No          | No           | Yes         | Yes         | Yes             |
# | Feature Selection         | No          | Yes         | Yes          | No          | Yes         | Yes             |
# | Threshold                 | 0.70        | 0.65        | 0.55         | 0.45        | 0.45        | 0.40            |
# | Accuracy                  | 0.8990      | 0.8930      | 0.8179       | 0.8714      | 0.8674      | 0.9059          |
# | Precision Score           | 0.4498      | 0.5155      | 0.3741       | 0.4635      | 0.4549      | 0.5718          |
# | Recall Score              | 0.9294      | 0.8106      | 0.9215       | 0.9121      | 0.9049      | 0.6501          |
# | F1 Score                  | 0.6062      | 0.5322      | 0.50151      | 0.6147      | 0.6054      | 0.6084          |
#
# Not any one model, is best in all scores. **Model 1**, **Model 3**, **Model 4,** and **Model 5** all have great Recall Score.
