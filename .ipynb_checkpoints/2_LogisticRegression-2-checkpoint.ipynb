# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
from utils.common_plot_tetha import plot_model
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder, OrdinalEncoder
from sklearn.compose import make_column_selector, make_column_transformer, ColumnTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as IPipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, make_scorer, confusion_matrix, fbeta_score
from sklearn.feature_selection import SelectFromModel
from imblearn.combine import SMOTETomek
from pprint import pprint
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 1. Read Data

# %%
df = pd.read_csv('bank+marketing/bank_clean.csv')

# %%
df.sample(3)
# Out:
#        age         job  marital    education default housing loan    contact  \
# 17232   50  technician  married   univ.grad.      no      no   no   cellular
# 10137   34    services  married  high.school      no      no   no  telephone
# 21900   31      admin.   single   univ.grad.      no     yes   no   cellular
#
#       month  duration  ...     poutcome  emp.var.rate cons.price.idx  \
# 17232   jul        95  ...  nonexistent           1.4         93.918
# 10137   jun        54  ...  nonexistent           1.4         94.465
# 21900   aug       138  ...  nonexistent           1.4         93.444
#
#        cons.conf.idx  euribor3m  nr.employed   y  balance day  \
# 17232          -42.7      4.962       5228.1  no        9  28
# 10137          -41.8      4.958       5228.1  no        0  11
# 21900          -36.1      4.964       5228.1  no        0  20
#
#        balance_transform
# 17232          -0.408568
# 10137          -0.416661
# 21900          -0.416661
#
# ...

# %% [markdown]
# # 2. Train Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop(['balance_transform','y','previous','poutcome','default'], axis=1), df['y'], test_size = 0.3, random_state = 42)

# %%
X_train.sample(3)
# Out:
#        age          job  marital   education housing loan    contact month  \
# 14279   29  blue-collar  married    basic.9y      no   no   cellular   jul
# 11278   51  blue-collar  married    basic.4y      no   no  telephone   jun
# 26262   34   management   single  univ.grad.     yes  yes   cellular   nov
#
#        duration  campaign  emp.var.rate  cons.price.idx  cons.conf.idx  \
# 14279       334         3           1.4          93.918          -42.7
# 11278        16         9           1.4          94.465          -41.8
# 26262       125         2          -0.1          93.200          -42.0
#
#        euribor3m  nr.employed  balance  day
# 14279      4.962       5228.1      248   14
# 11278      4.961       5228.1      519   18
# 26262      4.076       5195.8     1194   20

# %%
y_train.sample(3)
# Out:
# 25559     no
# 29172    yes
# 32700     no
# Name: y, dtype: object

# %%
obj_cat = X_train.select_dtypes(include=['object'])
obj_cat.columns
# Out:
# Index(['job', 'marital', 'education', 'housing', 'loan', 'contact', 'month'], dtype='object')

# %%
num_cat = X_train.select_dtypes(exclude=['object'])
num_cat.columns
# Out:
# Index(['age', 'duration', 'campaign', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'balance', 'day'],
#       dtype='object')

# %% [markdown]
# # 3. Column Transformation
# - OneHotEncoder for 'job','marital', 'contact', 'default', 'housing', 'loan', 'contact', 'month','poutcome'
# - OrdinalEncoder for education

# %%
education_categories = [['illiterate', 'basic.4y', 'basic.6y', 'basic.9y', 'high.school', 'university.degree','professional.course']]
one_hot_encoding_features = ['job', 'marital', 'housing', 'loan', 'contact', 'month']

transformer = make_column_transformer(    
    (OneHotEncoder(),one_hot_encoding_features),
    (OrdinalEncoder(categories=education_categories, unknown_value=-1, handle_unknown='use_encoded_value'),['education']),
    remainder = StandardScaler()
)

# %% [markdown]
# # 4. Pipeline

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "recall_score"<br>
# - Using combinition of OverSampling and Undersampling (SMOTE + Tomek) + Class Weight<br>
# - Followed by which we are doing Feature Selection <br>
# - Lastly used LogisticRegression  <br>
# - HyperParameter Tuning using GridSearchCV     <br>
# </div>

# %%
pipeline = IPipeline([
    ('transformer', transformer), 
    ('SMOTET', SMOTETomek(sampling_strategy = 'minority', random_state=42)),
    ('feature_selection', SelectFromModel(estimator=LogisticRegression(random_state=43, max_iter = 1000, C= 0.01, penalty= 'l1',solver= 'liblinear'))),
    ('classifier', LogisticRegression(random_state = 43, max_iter = 1000, class_weight='balanced'))
])

# %% [markdown]
# ## 4.1 GridSearchCV

# %%
params = [
    {     
        "classifier__C": [0.001, 0.01, 0.1, 10, 100],
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear'],
    },
    {
        "classifier__C": [ 0.01, 0.1, 10, 100],
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    },
    {
        "classifier__C": [0.01, 0.1, 10, 100],
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear']
    },
    {
        "classifier__C": [0.01, 0.1, 10, 100],
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    }
]

# %%
cv = GridSearchCV(pipeline, param_grid=params, n_jobs=-1, verbose=True, scoring=make_scorer(recall_score, pos_label='yes'))

# %% [markdown]
# ## 4.2. Fitting the LogisticRegression Model

# %%
cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 66 candidates, totalling 330 fits
# GridSearchCV(estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder=StandardScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month']),
# ...

# %%
pprint(cv.best_params_)
# Out:
# {'classifier__C': 0.001,
#  'classifier__penalty': 'l1',
#  'classifier__solver': 'liblinear'}

# %% [markdown]
# ## 4.3. Predictions

# %%
plot_model(cv, X_test, y_test)

# %%
probs = cv.predict_proba(X_test)
y_pred_1 = np.where(probs[:, 1] >= 0.70,  'yes','no')

# %% [markdown]
# ## 4.4 Scoring

# %% [markdown]
# ### 7.1 Accuracy
# Q) Out of the predictions made by the model, what percent is correct?
# <div align="center">
# $Accuracy =\Large \frac{(TP+TN))}{(TP+TN+FP+FN)}$
# </div>

# %%
accuracy = accuracy_score(y_test, y_pred_1)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8925305494861212

# %% [markdown]
# ### 7.2 Precision Score
# Q) Out of all the YES predictions, how many of them were correct?
# <div align="center">
# $Precision = \Large\frac{TP}{TP+FP}$
# </div>

# %%
p_score = precision_score(y_test, y_pred_1,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.5157949249093734

# %% [markdown]
# ### 7.3 Recall Score
# Q) Of all the actual positive cases, how many did the model capture?
# <div align="center">
# $Recall = \Large\frac{TP}{TP+FN}$
# </div>

# %%
r_score = recall_score(y_test, y_pred_1,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.7170626349892009

# %% [markdown]
# ### 7.4 F1 Score
# <div align="center">
# $F1 = \Large\frac{2*TP}{2*TP+FP+FN}$
# </div>

# %%
f_1_score = f1_score(y_test, y_pred_1, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_1).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(10249), np.int64(719), np.int64(498), np.int64(891))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_1);

# %%
best_pipeline = cv.best_estimator_

# %%
feature_selector = best_pipeline.named_steps['feature_selection']

# %%
selected_mask = feature_selector.get_support()

# %%
print(feature_selector.get_feature_names_out())
# Out:
# ['x0' 'x1' 'x12' 'x21' 'x23' 'x25' 'x29' 'x30' 'x31' 'x32' 'x34' 'x35'
#  'x36' 'x37' 'x38' 'x39' 'x40' 'x42' 'x44']

# %%
transformer = best_pipeline.named_steps['transformer']

# %%
transform_column = [' '.join(trans.split("__")[1].split('_')) for trans in transformer.get_feature_names_out()]

# %%
cols = [x for x, y in zip(transform_column, selected_mask) if y]
cols
# Out:
# ['job admin.',
#  'job blue-collar',
#  'marital divorced',
#  'loan yes',
#  'contact telephone',
#  'month aug',
#  'month mar',
#  'month may',
#  'month nov',
#  'month oct',
#  'education',
#  'age',
#  'duration',
#  'campaign',
#  'emp.var.rate',
#  'cons.price.idx',
#  'cons.conf.idx',
#  'nr.employed',
#  'day']

# %% [markdown]
# # 5. Pipeline

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "f1_score"<br>
# - Using combinition of OverSampling and Undersampling (SMOTE + Tomek) + Class Weight <br>
# - Followed by which we are doing Feature Selection <br>
# - Lastly used LogisticRegression  <br>
# - HyperParameter Tuning using GridSearchCV     <br>
# </div>

# %%
pipeline2 = IPipeline([
    ('transformer', transformer), 
    ('SMOTET', SMOTETomek(sampling_strategy = 'minority', random_state=42)),
    ('feature_selection', SelectFromModel(estimator=LogisticRegression(random_state=43, max_iter = 1000, C= 0.01, penalty= 'l1',solver= 'liblinear'))),
    ('classifier', LogisticRegression(random_state = 43, max_iter = 1000, class_weight='balanced'))
])

# %% [markdown]
# ## 5.1 GridSearchCV

# %%
params2 = [
    {     
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear'],
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    }
]

# %%
cv2 = GridSearchCV(pipeline2, param_grid=params2, n_jobs=-1, verbose=True, scoring=make_scorer(f1_score, pos_label='yes'))

# %% [markdown]
# ## 5.2. Fitting the LogisticRegression Model

# %%
cv2.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder=StandardScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month']),
# ...

# %%
pprint(cv2.best_params_)
# Out:
# {'classifier__C': 0.1,
#  'classifier__penalty': 'l1',
#  'classifier__solver': 'liblinear'}

# %% [markdown]
# ## 5.3 Predictions

# %%
plot_model(cv2, X_test, y_test)

# %%
probs = cv2.predict_proba(X_test)
y_pred_2 = np.where(probs[:, 1] >= 0.65,  'yes','no')

# %% [markdown]
# ## 5.4 Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_2)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8861374119932023

# %%
p_score = precision_score(y_test, y_pred_2,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.49601769911504423

# %%
r_score = recall_score(y_test, y_pred_2,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.8070554355651548

# %%
f_1_score = f1_score(y_test, y_pred_2, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6144149081940258

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_2).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9829), np.int64(1139), np.int64(268), np.int64(1121))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_2, values_format='d');

# %% [markdown]
# # 6. Pipeline - 3

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "fbeta_score"<br>
# - Using combinition of OverSampling and Undersampling (SMOTE + Tomek) - Class Weight<br>
# - Followed by which we are doing Feature Selection <br>
# - Lastly used LogisticRegression  <br>
# - HyperParameter Tuning using GridSearchCV     <br>
# </div>

# %%
pipeline3 = IPipeline([
    ('transformer', transformer), 
    ('SMOTET', SMOTETomek(sampling_strategy = 'minority', random_state=42)),
    ('feature_selection', SelectFromModel(estimator=LogisticRegression(random_state=43, max_iter = 1000, C= 0.01, penalty= 'l1',solver= 'liblinear'))),
    ('classifier', LogisticRegression(random_state = 43, max_iter = 1000, class_weight='balanced'))
])

# %% [markdown]
# ## 6.1 GridSearchCV

# %%
params3 = [
    {     
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear'],
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    }
]

# %%
cv3 = GridSearchCV(pipeline3, param_grid=params3, n_jobs=-1, verbose=True, scoring=make_scorer(fbeta_score, beta=2, pos_label='yes'))

# %% [markdown]
# ## 6.2. Fitting the LogisticRegression Model

# %%
cv3.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder=StandardScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month']),
# ...

# %%
pprint(cv3.best_params_)
# Out:
# {'classifier__C': 0.1,
#  'classifier__penalty': 'l1',
#  'classifier__solver': 'liblinear'}

# %% [markdown]
# ## 6.3 Predictions

# %%
plot_model(cv3, X_test, y_test)

# %%
# y_pred_3 = cv3.predict(X_test)

probs = cv3.predict_proba(X_test)
y_pred_3 = np.where(probs[:, 1] >= 0.65,  'yes','no')

# %% [markdown]
# ## 6.4 Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_3)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8861374119932023

# %%
p_score = precision_score(y_test, y_pred_3,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.49601769911504423

# %%
r_score = recall_score(y_test, y_pred_3,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.8070554355651548

# %%
f_1_score = f1_score(y_test, y_pred_3, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6144149081940258

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_3).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9829), np.int64(1139), np.int64(268), np.int64(1121))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_3, values_format='d');

# %% [markdown]
# # 7. Pipeline - 4

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "f1_score"<br>
# - Using combinition of OverSampling and Undersampling (SMOTE + Tomek) - No Class Weight<br>
# - Followed by which we are doing Feature Selection <br>
# - Lastly used LogisticRegression  <br>
# - HyperParameter Tuning using GridSearchCV     <br>
# </div>

# %%
pipeline4 = IPipeline([
    ('transformer', transformer), 
    ('SMOTET', SMOTETomek(sampling_strategy = 'minority', random_state=42)),
    ('feature_selection', SelectFromModel(estimator=LogisticRegression(random_state=43, max_iter = 1000, C= 0.01, penalty= 'l1',solver= 'liblinear'))),
    ('classifier', LogisticRegression(random_state = 43, max_iter = 1000))
])

# %% [markdown]
# ## 7.1 GridSearchCV

# %%
params4 = [
    {     
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear'],
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    }
]

# %%
cv4 = GridSearchCV(pipeline4, param_grid=params4, n_jobs=-1, verbose=True, scoring=make_scorer(f1_score, pos_label='yes'))

# %% [markdown]
# ## 7.2 Fitting the LogisticRegression Model

# %%
cv4.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder=StandardScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month']),
# ...

# %%
pprint(cv4.best_params_)
# Out:
# {'classifier__C': 0.1,
#  'classifier__penalty': 'l1',
#  'classifier__solver': 'liblinear'}

# %% [markdown]
# ## 7.3 Predictions

# %%
plot_model(cv4, X_test, y_test)

# %%
# y_pred_4 = cv4.predict(X_test)

probs = cv4.predict_proba(X_test)
y_pred_4 = np.where(probs[:, 1] >= 0.65,  'yes','no')

# %% [markdown]
# ## 7.4 Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_4)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8861374119932023

# %%
p_score = precision_score(y_test, y_pred_4,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.49601769911504423

# %%
r_score = recall_score(y_test, y_pred_4,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.8070554355651548

# %%
f_1_score = f1_score(y_test, y_pred_4, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6144149081940258

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_4).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9829), np.int64(1139), np.int64(268), np.int64(1121))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_4);

# %% [markdown]
# # 8. Pipeline - 5

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "f1_score"<br>
# - Using combinition of OverSampling and Undersampling (SMOTE + Tomek) - No Class Weight<br>
# - NO Feature Selection <br>
# - Lastly used LogisticRegression  <br>
# - HyperParameter Tuning using GridSearchCV     <br>
# </div>

# %%
pipeline5 = IPipeline([
    ('transformer', transformer), 
    ('SMOTET', SMOTETomek(sampling_strategy = 'minority', random_state=42)),
    ('classifier', LogisticRegression(random_state = 43, max_iter = 1000))
])

# %% [markdown]
# ## 8.1 GridSearchCV

# %%
params5 = [
    {     
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear'],
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    }
]

# %%
cv5 = GridSearchCV(pipeline5, param_grid=params5, n_jobs=-1, verbose=True, scoring=make_scorer(f1_score, pos_label='yes'))

# %% [markdown]
# ## 8.2 Fitting the LogisticRegression Model

# %%
cv5.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder=StandardScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month']),
# ...

# %%
pprint(cv5.best_params_)
# Out:
# {'classifier__C': 0.1,
#  'classifier__penalty': 'l2',
#  'classifier__solver': 'lbfgs'}

# %% [markdown]
# ## 8.3 Predictions

# %%
plot_model(cv5, X_test, y_test)

# %%
# y_pred_5 = cv5.predict(X_test)

probs = cv5.predict_proba(X_test)
y_pred_5 = np.where(probs[:, 1] >= 0.65,  'yes','no')

# %% [markdown]
# ## 8.4 Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_5)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8841142672169621

# %%
p_score = precision_score(y_test, y_pred_5,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.4904993371630579

# %%
r_score = recall_score(y_test, y_pred_5,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.7991360691144709

# %%
f_1_score = f1_score(y_test, y_pred_5, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6078860898138007

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_5).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9815), np.int64(1153), np.int64(279), np.int64(1110))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_5);

# %% [markdown]
# # 9. Pipeline - 6

# %% [markdown]
# <div class="alert alert-block alert-info">
# - Metric used here is "f1_score"<br>
# - Using combinition of OverSampling and Undersampling (SMOTE + Tomek) - with Class Weight<br>
# - NO Feature Selection <br>
# - Lastly used LogisticRegression  <br>
# - HyperParameter Tuning using GridSearchCV     <br>
# </div>

# %%
pipeline6 = IPipeline([
    ('transformer', transformer), 
    ('SMOTET', SMOTETomek(sampling_strategy = 'minority', random_state=42)),
    ('classifier', LogisticRegression(random_state = 43, max_iter = 1000, class_weight='balanced'))
])

# %% [markdown]
# ## 9.1 GridSearchCV

# %%
params6 = [
    {     
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear'],
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['liblinear']
    },
    {
        "classifier__C": [0.01, 0.1],    
        "classifier__penalty": ['l1', 'l2'],
        'classifier__solver': ['lbfgs','newton-cg', 'newton-cholesky']
    }
]

# %%
cv6 = GridSearchCV(pipeline6, param_grid=params6, n_jobs=-1, verbose=True, scoring=make_scorer(f1_score, pos_label='yes'))

# %% [markdown]
# ## 9.2 Fitting the LogisticRegression Model

# %%
cv6.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# GridSearchCV(estimator=Pipeline(steps=[('transformer',
#                                         ColumnTransformer(remainder=StandardScaler(),
#                                                           transformers=[('onehotencoder',
#                                                                          OneHotEncoder(),
#                                                                          ['job',
#                                                                           'marital',
#                                                                           'housing',
#                                                                           'loan',
#                                                                           'contact',
#                                                                           'month']),
# ...

# %%
pprint(cv6.best_params_)
# Out:
# {'classifier__C': 0.1,
#  'classifier__penalty': 'l2',
#  'classifier__solver': 'lbfgs'}

# %% [markdown]
# ## 9.3 Predictions

# %%
plot_model(cv6, X_test, y_test)

# %%
# y_pred_6 = cv6.predict(X_test)

probs = cv6.predict_proba(X_test)
y_pred_6 = np.where(probs[:, 1] >= 0.65,  'yes','no')

# %% [markdown]
# ## 9.4 Scoring

# %%
accuracy = accuracy_score(y_test, y_pred_6)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8841142672169621

# %%
p_score = precision_score(y_test, y_pred_6,pos_label='yes')
print("Precision Score:", p_score)
# Out:
# Precision Score: 0.4904993371630579

# %%
r_score = recall_score(y_test, y_pred_6,pos_label='yes')
print("Recall Score", r_score)
# Out:
# Recall Score 0.7991360691144709

# %%
f_1_score = f1_score(y_test, y_pred_6, pos_label='yes')
print("F1 Score", f_1_score)
# Out:
# F1 Score 0.6078860898138007

# %%
tn, fp, fn, tp = confusion_matrix(y_test, y_pred_6).ravel()
tn, fp, fn, tp
# Out:
# (np.int64(9815), np.int64(1153), np.int64(279), np.int64(1110))

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred_6);

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1>Logistic Regression - Conclusion</h1>
# </div>

# %% [markdown]
# |                           | Model 1      | Model 2    | Model 3     | Model 4    | Model 5    | Model 6    |
# | :------------------------ | :----------- | :--------- | ----------- | ---------- | ---------- | ---------- |
# | Metric                    | recall_score | f1_score   | fbeta_score | f1_score   | f1_score   | f1_score   |
# | Data Sampling Algorithms  | SMOTETomek   | SMOTETomek | SMOTETomek  | SMOTETomek | SMOTETomek | SMOTETomek |
# | Cost-Sensitive Algorithms | Yes          | Yes        | Yes         | No         | No         | Yes        |
# | Feature Selection         | Yes          | Yes        | Yes         | Yes        | No         | No         |
# | Threshold                 | 0.70         | 0.65       | 0.65        | 0.65       | 0.65       | 0.65       |
# | Accuracy                  | 0.8925       | 0.8861     | 0.8861      | 0.8861     | 0.8841     | 0.8841     |
# | Precision Score           | 0.5157       | 0.4960     | 0.4960      | 0.4960     | 0.4904     | 0.4904     |
# | Recall Score              | 0.7170       | 0.8070     | 0.8070      | 0.8070     | 0.7991     | 0.7991     |
# | F1 Score                  | 0.6000       | 0.6144     | 0.6144      | 0.6144     | 0.6078     | 0.6078     |
